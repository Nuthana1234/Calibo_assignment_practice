# %% [markdown]
# <a href="https://colab.research.google.com/github/Nuthana1234/Calibo_assignment_practice/blob/main/calibo_session_21/9/2026-23/9/26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd
print("Version available is:",pd.__version__)
# Out:
# Version available is: 2.2.3

# %%
import pandas as pd
#print(pd.__version__)
marks = pd.Series([85,90,70,80], name='marks')
print(marks)
student_marks = pd.Series([85,90,95,99,100,53,67,85,76],
                          index = ["Priya","Ravi","Varun","Shyam","Rosy","Sneha","Kavya","Maddie","Sweety"])
print(student_marks)
print("Priya's marks:",student_marks["Priya"])
# Out:
# 0    85
# 1    90
# 2    70
# 3    80
# Name: marks, dtype: int64
# Priya      85
# Ravi       90
# Varun      95
# Shyam      99
# Rosy      100
# Sneha      53
# Kavya      67
# Maddie     85
# Sweety     76
# dtype: int64
# Priya's marks: 85

# %% [markdown]
# ### 🎯 Your Task:
# Using **Pandas Series**, perform the following:
# ✅ Create a Series named `scores` using the dictionary `student_scores`.
# ✅ Print the marks scored by **"Charlie"** and **"Eva"**.
# ✅ Add **5 bonus marks** to all students and print the updated Series.
# ✅ Display only the students who scored **above 90** after the bonus.
# ✅ Calculate and print the **average marks** of the class (after the bonus).

# %%
import pandas as pd

# Sample dictionary containing student names and their initial scores
student_scores = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78,
    "David": 88,
    "Eva": 95
}

# 1. Create a Pandas Series named 'scores'
scores = pd.Series(student_scores)

# 2. Print the marks scored by "Charlie" and "Eva"
print("--- Marks for Charlie and Eva ---")
print(f"Charlie: {scores['Charlie']}")
print(f"Eva: {scores['Eva']}\n")

# 3. Add 5 bonus marks to all students and print the updated Series
scores = scores + 5
print("--- Updated Scores (with +5 Bonus Marks) ---")
print(scores)
print()

# 4. Display only the students who scored above 90 after the bonus
print("--- Students Scoring Above 90 After Bonus ---")
print(scores[scores > 90])
print()

# 5. Calculate and print the average marks of the class
average_marks = scores.mean()
print(f"--- Class Average (After Bonus) ---")
print(f"Average Marks: {average_marks}")
# Out:
# --- Marks for Charlie and Eva ---
# Charlie: 78
# Eva: 95
#
# --- Updated Scores (with +5 Bonus Marks) ---
# Alice       90
# Bob         97
# Charlie     83
# David       93
# Eva        100
# dtype: int64
#
# --- Students Scoring Above 90 After Bonus ---
# Bob       97
# David     93
# Eva      100
# dtype: int64
#
# --- Class Average (After Bonus) ---
# Average Marks: 92.6

# %%
import pandas as pd
import numpy as np
data = [
    ["Ravi",21,85],
    ["Priiya",20,92],
    ["Arun",22,76]
]
pd.DataFrame(data, columns=["Name","Age","Marks"])
arr = np.array([[1,80],[2,90],[3,75]])
pd.DataFrame(arr,columns=["Student_ID","marks"])
# Out:
#    Student_ID  marks
# 0           1     80
# 1           2     90
# 2           3     75

# %%
import numpy as np
import pandas as pd

data = ["Ravi", "Prasadi", "Gihan", "Hansana"]

# Fix 1: Wrap the rows inside an outer list to make a proper 2D array
arr = np.array([[25, 85], [25, 90], [26, 70], [24, 80]])

# Fix 2: Correct the spelling of 'columns' and pass them as a list
df = pd.DataFrame(arr, columns=["Age", "Marks"])

# Optional: Add the names as the index so the data aligns
df.index = data

df
# Out:
#          Age  Marks
# Ravi      25     85
# Prasadi   25     90
# Gihan     26     70
# Hansana   24     80

# %%
import pandas as pd

a_dict = {
    'name': {'Ru': 'Rukshan', 'Pr': 'Prasadi', 'Gi': 'Gihan', 'Ha': 'Hansana'},
    'age': {'Ru': 25, 'Pr': 25, 'Gi': 26, 'Ha': 24},
    'marks': {'Ru': 85, 'Pr': 90, 'Gi': 70, 'Ha': 80}
}

df = pd.DataFrame(a_dict)
df
# Out:
#        name  age  marks
# Ru  Rukshan   25     85
# Pr  Prasadi   25     90
# Gi    Gihan   26     70
# Ha  Hansana   24     80

# %%
import pandas as pd

ser1 = pd.Series(['Rukshan', 'Prasadi', 'Gihan', 'Hansana'], index=['Ru', 'Pr', 'Gi', 'Ha'])
ser2 = pd.Series([25, 25, 26, 24], index=['Ru', 'Pr', 'Gi', 'Ha'])
ser3 = pd.Series([85, 90, 70, 80], index=['Ru', 'Pr', 'Gi', 'Ha'])

a_dict = {
    'name': ser1,
    'age': ser2,
    'marks': ser3
}

df = pd.DataFrame(a_dict)
df
# Out:
#        name  age  marks
# Ru  Rukshan   25     85
# Pr  Prasadi   25     90
# Gi    Gihan   26     70
# Ha  Hansana   24     80

# %% [markdown]
# 🧠 Python Pandas Logical Practice Task
# You are given three Series representing student data:
# Names of students
# Their ages
# Their marks
# These series are combined into a DataFrame as shown earlier.
# 🎯 Your Task:
# Using the existing DataFrame, perform the following operations:
# ✅ Print the details (name, age, marks) of the student who scored the highest marks.
# ✅ Add a new student "Tharushi" with age 23 and marks 88 using the index "Th".
# ✅ Display the details of students who are 25 years old or older.
# ✅ Increase the marks of students below 80 by 10 bonus points.
# ✅ Calculate and print the average marks of all students after the bonus.

# %%
import pandas as pd
name = pd.Series(["Alice","Bob","Charlie","David"])
age = pd.Series([22,21,20,21])
marks = pd.Series([95,98,93,92])
index_labels = pd.Series(["Al","Bb","ch","Dd"])
df = pd.DataFrame({"Name": name, "Age": age, "Marks": marks})
df.index = index_labels
df
highest_student = df.loc[df['Marks'].idxmax()]
print("--- Highest Scoring Student ---")
print(highest_student)
print()
df.loc["Th"] = ["Tharushi", 23, 88]
print("--- DataFrame After Adding Tharushi ---")
print(df)
print()
older_students = df[df['Age'] >= 25]
print("--- Students 25 or Older ---")
print(older_students)
print()
df.loc[df['Marks'] < 80, 'Marks'] += 10
print("--- DataFrame After Applying Bonus ---")
print(df)
print()

# ✅ 5. Calculate and print the average marks after the bonus
average_marks = df['Marks'].mean()
print(f"Average Marks of all students: {average_marks:.2f}")
# Out:
# --- Highest Scoring Student ---
# Name     Bob
# Age       21
# Marks     98
# Name: Bb, dtype: object
#
# --- DataFrame After Adding Tharushi ---
#         Name  Age  Marks
# Al     Alice   22     95
# Bb       Bob   21     98
# ch   Charlie   20     93
# Dd     David   21     92
# Th  Tharushi   23     88
#
# --- Students 25 or Older ---
# Empty DataFrame
# Columns: [Name, Age, Marks]
# Index: []
#
# --- DataFrame After Applying Bonus ---
#         Name  Age  Marks
# Al     Alice   22     95
# Bb       Bob   21     98
# ch   Charlie   20     93
# Dd     David   21     92
# Th  Tharushi   23     88
#
# Average Marks of all students: 93.20

# %% [markdown]
# Working with dataset

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("/content/Student_Performance.csv")
#displaying first 10 rows in the dataset
df.head(10)
# Out:
#    Student_ID       Name  Age  Gender    Department  Attendance  Study_Hours  \
# 0        1001       Ravi   21  Female  Data Science        84.0          5.5
# 1        1002      Priya   23    Male         Cloud        76.1          8.4
# 2        1003       Arun   23  Female        Python        98.9          2.0
# 3        1004      Meena   21    Male  Data Science        97.9          3.6
# 4        1005      Kiran   22    Male            AI         NaN          2.8
# 5        1006     Suresh   20  Female            AI        95.4          3.4
# 6        1007     Anjali   24  Female            AI        73.8          4.9
# 7        1008      Rahul   20    Male           ai         76.6          4.1
# 8        1009      Divya   20  Female  Data Science        89.7          4.3
# 9        1010    Rahul     22  Female        Python        94.2          7.4
#
#    Assignment_Score  Exam_Score           City Enrollment_Date Fee_Status  \
# ...

# %%
#to dsiplay last 5 rows
df.tail()
# Out:
#     Student_ID     Name  Age Gender Department  Attendance  Study_Hours  \
# 56        1057   Venkat   22   Male         AI        91.2          2.5
# 57        1058  Sahithi   23   Male         AI        97.5          2.4
# 58        1059    Akash   21   Male         AI        78.3          8.3
# 59        1060  Madhavi   20   Male         AI        85.1          6.5
# 60        1012    Manoj   21   Male      Cloud        80.5          2.0
#
#     Assignment_Score  Exam_Score       City Enrollment_Date Fee_Status  \
# 56                81          64  Hyderabad      2026-06-22       Paid
# 57                67          56  Bengaluru      2026-06-25       Paid
# 58                54          99  Hyderabad      2026-06-28    Pending
# 59                98          99  Hyderabad      2026-07-01       Paid
# 60                97          73    Chennai      2026-02-07       Paid
#
#    Placement_Status
# 56       Not Placed
# 57       Not Placed
# 58           Placed
# ...

# %%
# to get information regarding the csv dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student_ID        61 non-null     int64
#  1   Name              61 non-null     object
#  2   Age               61 non-null     int64
#  3   Gender            61 non-null     object
#  4   Department        60 non-null     object
#  5   Attendance        59 non-null     float64
#  6   Study_Hours       59 non-null     float64
#  7   Assignment_Score  61 non-null     int64
#  8   Exam_Score        61 non-null     int64
#  9   City              61 non-null     object
#  10  Enrollment_Date   61 non-null     object
#  11  Fee_Status        61 non-null     object
#  12  Placement_Status  61 non-null     object
# dtypes: float64(2), int64(4), object(7)
# memory usage: 6.3+ KB

# %%
# to determine the rows and columns
df.shape
# Out:
# (61, 13)

# %%
df.size
# Out:
# 793

# %%
df.describe()
# Out:
#         Student_ID        Age  Attendance  Study_Hours  Assignment_Score  \
# count    61.000000  61.000000   59.000000    59.000000         61.000000
# mean   1030.196721  21.688525   86.084746     4.633898         72.688525
# std      17.479340   1.297960    8.569328     2.084475         15.941080
# min    1001.000000  20.000000   68.600000     1.500000         45.000000
# 25%    1015.000000  21.000000   79.150000     2.950000         60.000000
# 50%    1030.000000  22.000000   85.100000     4.300000         72.000000
# 75%    1045.000000  23.000000   94.450000     6.300000         84.000000
# max    1060.000000  24.000000   98.900000     8.400000         98.000000
#
#        Exam_Score
# count   61.000000
# mean    80.147541
# std     14.473926
# min     53.000000
# 25%     70.000000
# 50%     80.000000
# 75%     95.000000
# max     99.000000

# %%
print("Departments")
print(df["Department"])
print("-------Unique Departments")
print(df["Department"].unique)
print("--------Count of departments----------")
print(df["Department"].value_counts())
# Out:
# Departments
# 0     Data Science
# 1            Cloud
# 2           Python
# 3     Data Science
# 4               AI
#           ...
# 56              AI
# 57              AI
# 58              AI
# 59              AI
# 60           Cloud
# Name: Department, Length: 61, dtype: object
# -------Unique Departments
# <bound method Series.unique of 0     Data Science
# 1            Cloud
# 2           Python
# 3     Data Science
# 4               AI
#           ...
# 56              AI
# 57              AI
# 58              AI
# 59              AI
# 60           Cloud
# Name: Department, Length: 61, dtype: object>
# --------Count of departments----------
# Department
# AI              25
# Data Science    16
# Cloud           10
# Python           6
#  ai              1
# data science     1
# python           1
# Name: count, dtype: int64

# %%
#To print Column Exam_Score
df["Exam_Score"]
df
# Out:
#     Student_ID     Name  Age  Gender    Department  Attendance  Study_Hours  \
# 0         1001     Ravi   21  Female  Data Science        84.0          5.5
# 1         1002    Priya   23    Male         Cloud        76.1          8.4
# 2         1003     Arun   23  Female        Python        98.9          2.0
# 3         1004    Meena   21    Male  Data Science        97.9          3.6
# 4         1005    Kiran   22    Male            AI         NaN          2.8
# ..         ...      ...  ...     ...           ...         ...          ...
# 56        1057   Venkat   22    Male            AI        91.2          2.5
# 57        1058  Sahithi   23    Male            AI        97.5          2.4
# 58        1059    Akash   21    Male            AI        78.3          8.3
# 59        1060  Madhavi   20    Male            AI        85.1          6.5
# 60        1012    Manoj   21    Male         Cloud        80.5          2.0
#
# ...

# %%
# To get 3 columns name,dept,exam-score
df[["Name","Department","Exam_Score"]]
df
# Out:
#     Student_ID     Name  Age  Gender    Department  Attendance  Study_Hours  \
# 0         1001     Ravi   21  Female  Data Science        84.0          5.5
# 1         1002    Priya   23    Male         Cloud        76.1          8.4
# 2         1003     Arun   23  Female        Python        98.9          2.0
# 3         1004    Meena   21    Male  Data Science        97.9          3.6
# 4         1005    Kiran   22    Male            AI         NaN          2.8
# ..         ...      ...  ...     ...           ...         ...          ...
# 56        1057   Venkat   22    Male            AI        91.2          2.5
# 57        1058  Sahithi   23    Male            AI        97.5          2.4
# 58        1059    Akash   21    Male            AI        78.3          8.3
# 59        1060  Madhavi   20    Male            AI        85.1          6.5
# 60        1012    Manoj   21    Male         Cloud        80.5          2.0
#
# ...

# %%
#TO understand label-based indexing
#loc-label based indexing
display(df.loc[0])
# Out:
# Student_ID                   1001
# Name                         Ravi
# Age                            21
# Gender                     Female
# Department           Data Science
# Attendance                   84.0
# Study_Hours                   5.5
# Assignment_Score               63
# Exam_Score                     78
# City                Visakhapatnam
# Enrollment_Date        2026-01-05
# Fee_Status                   Paid
# Placement_Status           Placed
# Name: 0, dtype: object

# %%
#To get first person's exam_score
print("Specific value:")
display(df.loc[0,"Exam_Score"])
# Out:
# Specific value:
# np.int64(78)

# %%
df.iloc[0:5,0:4]
df
# Out:
#     Student_ID     Name  Age  Gender    Department  Attendance  Study_Hours  \
# 0         1001     Ravi   21  Female  Data Science        84.0          5.5
# 1         1002    Priya   23    Male         Cloud        76.1          8.4
# 2         1003     Arun   23  Female        Python        98.9          2.0
# 3         1004    Meena   21    Male  Data Science        97.9          3.6
# 4         1005    Kiran   22    Male            AI         NaN          2.8
# ..         ...      ...  ...     ...           ...         ...          ...
# 56        1057   Venkat   22    Male            AI        91.2          2.5
# 57        1058  Sahithi   23    Male            AI        97.5          2.4
# 58        1059    Akash   21    Male            AI        78.3          8.3
# 59        1060  Madhavi   20    Male            AI        85.1          6.5
# 60        1012    Manoj   21    Male         Cloud        80.5          2.0
#
# ...

# %%
print("Students with exam score >80:")
display(df[df["Exam_Score"]>80])
# Out:
# Students with exam score >80:
#     Student_ID       Name  Age  Gender    Department  Attendance  Study_Hours  \
# 1         1002      Priya   23    Male         Cloud        76.1          8.4
# 7         1008      Rahul   20    Male           ai         76.6          4.1
# 9         1010    Rahul     22  Female        Python        94.2          7.4
# 10        1011      Sneha   20  Female            AI        94.5          8.0
# 13        1014     Naveen   23    Male  data science        94.4          6.2
# 14        1015      Pooja   24    Male            AI        97.0          4.0
# 16        1017     Swathi   20    Male            AI        88.7          3.6
# 18        1019    Keerthi   21    Male  Data Science        79.5          7.4
# 20        1021    Lakshmi   23  Female  Data Science        98.2          6.5
# 21        1022      Varun   21    Male            AI        76.8          5.4
# 22        1023       Asha   23  Female            AI        77.5          3.6
# ...

# %%
print("Students Attendance > 85:")
display(df[df["Attendance"]>85])
# Out:
# Students Attendance > 85:
#     Student_ID       Name  Age  Gender    Department  Attendance  Study_Hours  \
# 2         1003       Arun   23  Female        Python        98.9          2.0
# 3         1004      Meena   21    Male  Data Science        97.9          3.6
# 5         1006     Suresh   20  Female            AI        95.4          3.4
# 8         1009      Divya   20  Female  Data Science        89.7          4.3
# 9         1010    Rahul     22  Female        Python        94.2          7.4
# 10        1011      Sneha   20  Female            AI        94.5          8.0
# 12        1013      Kavya   21    Male        Python        95.5          3.0
# 13        1014     Naveen   23    Male  data science        94.4          6.2
# 14        1015      Pooja   24    Male            AI        97.0          4.0
# 15        1016     Harish   20    Male            AI        92.3          3.3
# 16        1017     Swathi   20    Male            AI        88.7          3.6
# ...

# %%
print("Students with exam_score >80 and Attendance :85" )
result = df[(df["Exam_Score"]>80) &(df["Attendance"]>85)]
#print(result)
df
# Out:
# Students with exam_score >80 and Attendance :85
#     Student_ID     Name  Age  Gender    Department  Attendance  Study_Hours  \
# 0         1001     Ravi   21  Female  Data Science        84.0          5.5
# 1         1002    Priya   23    Male         Cloud        76.1          8.4
# 2         1003     Arun   23  Female        Python        98.9          2.0
# 3         1004    Meena   21    Male  Data Science        97.9          3.6
# 4         1005    Kiran   22    Male            AI         NaN          2.8
# ..         ...      ...  ...     ...           ...         ...          ...
# 56        1057   Venkat   22    Male            AI        91.2          2.5
# 57        1058  Sahithi   23    Male            AI        97.5          2.4
# 58        1059    Akash   21    Male            AI        78.3          8.3
# 59        1060  Madhavi   20    Male            AI        85.1          6.5
# 60        1012    Manoj   21    Male         Cloud        80.5          2.0
#
# ...

# %%
print("Highest Exam_Score:")
display(df.sort_values("Exam_Score",ascending = False).head(10))
print("Lowest Attendance:")
# Out:
# Highest Exam_Score:
#     Student_ID      Name  Age  Gender    Department  Attendance  Study_Hours  \
# 1         1002     Priya   23    Male         Cloud        76.1          8.4
# 18        1019   Keerthi   21    Male  Data Science        79.5          7.4
# 20        1021   Lakshmi   23  Female  Data Science        98.2          6.5
# 40        1041    Rakesh   22    Male            AI        83.1          8.4
# 59        1060   Madhavi   20    Male            AI        85.1          6.5
# 48        1049  Abhishek   21    Male  Data Science        83.5          7.3
# 50        1051    Lokesh   22  Female         Cloud        91.8          8.3
# 52        1053    Chandu   20    Male         Cloud        98.8          7.4
# 55        1056  Bhargavi   21  Female         Cloud        95.4          6.4
# 58        1059     Akash   21    Male            AI        78.3          8.3
#
#     Assignment_Score  Exam_Score           City Enrollment_Date Fee_Status  \
# ...

# %%
#Add and modify the problems
#a copy of the csv dataset is made which is stored in work
work = df.copy()
#creating
work["Passed"] = work["Exam_Score"] >= 50
work["Total_Score"] = work["Exam_Score"] + work["Assignment_Score"]
work["Average_Score"] = work[["Total_Score"]].mean(axis=1)
work.head(10)
# Out:
#    Student_ID       Name  Age  Gender    Department  Attendance  Study_Hours  \
# 0        1001       Ravi   21  Female  Data Science        84.0          5.5
# 1        1002      Priya   23    Male         Cloud        76.1          8.4
# 2        1003       Arun   23  Female        Python        98.9          2.0
# 3        1004      Meena   21    Male  Data Science        97.9          3.6
# 4        1005      Kiran   22    Male            AI         NaN          2.8
# 5        1006     Suresh   20  Female            AI        95.4          3.4
# 6        1007     Anjali   24  Female            AI        73.8          4.9
# 7        1008      Rahul   20    Male           ai         76.6          4.1
# 8        1009      Divya   20  Female  Data Science        89.7          4.3
# 9        1010    Rahul     22  Female        Python        94.2          7.4
#
#    Assignment_Score  Exam_Score           City Enrollment_Date Fee_Status  \
# ...

# %%
display(work[["Exam_Score","Assignment_Score","Average_Score"]])
# Out:
#     Exam_Score  Assignment_Score  Average_Score
# 0           78                63          141.0
# 1           99                61          160.0
# 2           70                63          133.0
# 3           64                72          136.0
# 4           76                70          146.0
# ..         ...               ...            ...
# 56          64                81          145.0
# 57          56                67          123.0
# 58          99                54          153.0
# 59          99                98          197.0
# 60          73                97          170.0
#
# [61 rows x 3 columns]

# %%
#Feature Engineering
import numpy as np
work["Performance_Level"] = np.where(
    work["Exam_Score"] >= 85,"Excellent",
    np.where(work["Exam_Score"] >= 70,"Good","Needs Improvement")

)
display(work[["Name","Performance_Level"]].head(10))
# Out:
#         Name  Performance_Level
# 0       Ravi               Good
# 1      Priya          Excellent
# 2       Arun               Good
# 3      Meena  Needs Improvement
# 4      Kiran               Good
# 5     Suresh               Good
# 6     Anjali               Good
# 7      Rahul          Excellent
# 8      Divya               Good
# 9    Rahul                 Good

# %%
renamed = df.rename(columns={
    "Exam_Score": "Final_Exam_Score",
    "Study_Hours":"Daily_Study_Hours"
})
renamed.head()
# Out:
#    Student_ID   Name  Age  Gender    Department  Attendance  \
# 0        1001   Ravi   21  Female  Data Science        84.0
# 1        1002  Priya   23    Male         Cloud        76.1
# 2        1003   Arun   23  Female        Python        98.9
# 3        1004  Meena   21    Male  Data Science        97.9
# 4        1005  Kiran   22    Male            AI         NaN
#
#    Daily_Study_Hours  Assignment_Score  Final_Exam_Score           City  \
# 0                5.5                63                78  Visakhapatnam
# 1                8.4                61                99        Chennai
# 2                2.0                63                70      Hyderabad
# 3                3.6                72                64  Visakhapatnam
# 4                2.8                70                76     Vijayawada
#
#   Enrollment_Date Fee_Status Placement_Status
# 0      2026-01-05       Paid           Placed
# 1      2026-01-08       Paid           Placed
# ...

# %%
example = work.drop(columns = "Total_Score")
example.head()
# Out:
#    Student_ID   Name  Age  Gender    Department  Attendance  Study_Hours  \
# 0        1001   Ravi   21  Female  Data Science        84.0          5.5
# 1        1002  Priya   23    Male         Cloud        76.1          8.4
# 2        1003   Arun   23  Female        Python        98.9          2.0
# 3        1004  Meena   21    Male  Data Science        97.9          3.6
# 4        1005  Kiran   22    Male            AI         NaN          2.8
#
#    Assignment_Score  Exam_Score           City Enrollment_Date Fee_Status  \
# 0                63          78  Visakhapatnam      2026-01-05       Paid
# 1                61          99        Chennai      2026-01-08       Paid
# 2                63          70      Hyderabad      2026-01-11       Paid
# 3                72          64  Visakhapatnam      2026-01-14       Paid
# 4                70          76     Vijayawada      2026-01-17       Paid
#
#   Placement_Status  Passed  Average_Score  Performance_Level
# ...

# %%
df
# Out:
#     Student_ID     Name  Age  Gender    Department  Attendance  Study_Hours  \
# 0         1001     Ravi   21  Female  Data Science        84.0          5.5
# 1         1002    Priya   23    Male         Cloud        76.1          8.4
# 2         1003     Arun   23  Female        Python        98.9          2.0
# 3         1004    Meena   21    Male  Data Science        97.9          3.6
# 4         1005    Kiran   22    Male            AI         NaN          2.8
# ..         ...      ...  ...     ...           ...         ...          ...
# 56        1057   Venkat   22    Male            AI        91.2          2.5
# 57        1058  Sahithi   23    Male            AI        97.5          2.4
# 58        1059    Akash   21    Male            AI        78.3          8.3
# 59        1060  Madhavi   20    Male            AI        85.1          6.5
# 60        1012    Manoj   21    Male         Cloud        80.5          2.0
#
# ...

# %%
work
# Out:
#     Student_ID     Name  Age  Gender    Department  Attendance  Study_Hours  \
# 0         1001     Ravi   21  Female  Data Science        84.0          5.5
# 1         1002    Priya   23    Male         Cloud        76.1          8.4
# 2         1003     Arun   23  Female        Python        98.9          2.0
# 3         1004    Meena   21    Male  Data Science        97.9          3.6
# 4         1005    Kiran   22    Male            AI         NaN          2.8
# ..         ...      ...  ...     ...           ...         ...          ...
# 56        1057   Venkat   22    Male            AI        91.2          2.5
# 57        1058  Sahithi   23    Male            AI        97.5          2.4
# 58        1059    Akash   21    Male            AI        78.3          8.3
# 59        1060  Madhavi   20    Male            AI        85.1          6.5
# 60        1012    Manoj   21    Male         Cloud        80.5          2.0
#
# ...

# %%
example1 = work.drop([0,1])
example1.head()
# Out:
#    Student_ID    Name  Age  Gender    Department  Attendance  Study_Hours  \
# 2        1003    Arun   23  Female        Python        98.9          2.0
# 3        1004   Meena   21    Male  Data Science        97.9          3.6
# 4        1005   Kiran   22    Male            AI         NaN          2.8
# 5        1006  Suresh   20  Female            AI        95.4          3.4
# 6        1007  Anjali   24  Female            AI        73.8          4.9
#
#    Assignment_Score  Exam_Score           City Enrollment_Date Fee_Status  \
# 2                63          70      Hyderabad      2026-01-11       Paid
# 3                72          64  Visakhapatnam      2026-01-14       Paid
# 4                70          76     Vijayawada      2026-01-17       Paid
# 5                81          77        Chennai      2026-01-20       Paid
# 6                70          74      Hyderabad      2026-01-23       Paid
#
#   Placement_Status  Passed  Total_Score  Average_Score  Performance_Level
# ...

# %%
print("How many missing values by column")
display(df.isna().sum())
# Out:
# How many missing values by column
# Student_ID          0
# Name                0
# Age                 0
# Gender              0
# Department          1
# Attendance          2
# Study_Hours         2
# Assignment_Score    0
# Exam_Score          0
# City                0
# Enrollment_Date     0
# Fee_Status          0
# Placement_Status    0
# dtype: int64

# %%
display(df.isna().sum().sum())
df.shape
# Out:
# np.int64(5)
# (61, 13)

# %%
complete = df.dropna().sum()
complete.shape
# Out:
# (13,)

# %%
complete.head()
# Out:
# Student_ID                                                57693
# Name          RaviPriyaArunMeenaSureshAnjaliRahulDivya  Rahu...
# Age                                                        1212
# Gender        FemaleMaleFemaleMaleFemaleFemaleMaleFemaleFema...
# Department    Data ScienceCloudPythonData ScienceAIAI ai Dat...
# dtype: object

# %%
filled = df.copy()
filled["Attendance"] = filled["Attendance"].fillna(
    filled["Attendance"].median()
    )
filled["Study_Hours"] = filled["Study_Hours"].fillna(
    filled["Study_Hours"].median()
)
filled["Department"] = filled["Department"].fillna("Unknown")
print("Remaining missing values:")
print(filled.isna().sum())
# Out:
# Remaining missing values:
# Student_ID          0
# Name                0
# Age                 0
# Gender              0
# Department          0
# Attendance          0
# Study_Hours         0
# Assignment_Score    0
# Exam_Score          0
# City                0
# Enrollment_Date     0
# Fee_Status          0
# Placement_Status    0
# dtype: int64

# %% [markdown]
# Duplicates identification and removal

# %%
print("Duplicate rows:",df.duplicated().sum())
print("Duplicate record:")
display(df[df.duplicated(keep = False)])
df_no_duplicate = df.drop_duplicates()
print("Shape after removing duplicates",df_no_duplicate.shape)
# Out:
# Duplicate rows: 1
# Duplicate record:
#     Student_ID   Name  Age Gender Department  Attendance  Study_Hours  \
# 11        1012  Manoj   21   Male      Cloud        80.5          2.0
# 60        1012  Manoj   21   Male      Cloud        80.5          2.0
#
#     Assignment_Score  Exam_Score     City Enrollment_Date Fee_Status  \
# 11                97          73  Chennai      2026-02-07       Paid
# 60                97          73  Chennai      2026-02-07       Paid
#
#    Placement_Status
# 11           Placed
# 60           Placed
# Shape after removing duplicates (60, 13)

# %% [markdown]
# **Any Columns contains strings**

# %%
names = pd.Series(["rama ","Priya "," Radhika"," Hasini"])
print("Clean Spaces")
print(names.str.strip())
print("Lowercase")
print(names.str.lower())
print("Upper Case")
print(names.str.upper())
print("Title Case")
print(names.str.title())
# Out:
# Clean Spaces
# 0       rama
# 1      Priya
# 2    Radhika
# 3     Hasini
# dtype: object
# Lowercase
# 0       rama
# 1      priya
# 2     radhika
# 3      hasini
# dtype: object
# Upper Case
# 0       RAMA
# 1      PRIYA
# 2     RADHIKA
# 3      HASINI
# dtype: object
# Title Case
# 0       Rama
# 1      Priya
# 2     Radhika
# 3      Hasini
# dtype: object

# %%
df.dtypes
# Out:
# Student_ID            int64
# Name                 object
# Age                   int64
# Gender               object
# Department           object
# Attendance          float64
# Study_Hours         float64
# Assignment_Score      int64
# Exam_Score            int64
# City                 object
# Enrollment_Date      object
# Fee_Status           object
# Placement_Status     object
# dtype: object

# %%
demo = pd.DataFrame({
    "Marks":["80","92","Invalid","75"]
})
demo["Marks"] = pd.to_numeric(demo["Marks"],errors = "coerce")
print(demo)
demo.dtypes
# Out:
#    Marks
# 0   80.0
# 1   92.0
# 2    NaN
# 3   75.0
# Marks    float64
# dtype: object

# %% [markdown]
# groupby()

# %%
clean = df.copy()
dept_avg = (
    clean.groupby("Department")["Exam_Score"]
    .mean()
    .sort_values(ascending = False)
)
dept_avg
# Out:
# Department
#  ai             91.000000
# python          88.000000
# Cloud           87.900000
# data science    82.000000
# AI              79.320000
# Python          77.333333
# Data Science    76.562500
# Name: Exam_Score, dtype: float64

# %%
clean = df.copy()
dept_avg = (
    clean.groupby("Department")["Exam_Score"]
    .agg(["count","mean","min","max"])
    .round(2)
)
dept_avg
# Out:
#               count   mean  min  max
# Department
#  ai               1  91.00   91   91
# AI               25  79.32   53   99
# Cloud            10  87.90   72   99
# Data Science     16  76.56   54   99
# Python            6  77.33   59   98
# data science      1  82.00   82   82
# python            1  88.00   88   88
